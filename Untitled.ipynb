# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import os
import pandas as pd
from pandas import DataFrame
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
for dirname, _, filenames in os.walk('archive'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# archive\coin_Aave.csv
# archive\coin_BinanceCoin.csv
# archive\coin_Bitcoin.csv
# archive\coin_Cardano.csv
# archive\coin_ChainLink.csv
# archive\coin_Cosmos.csv
# archive\coin_CryptocomCoin.csv
# archive\coin_Dogecoin.csv
# archive\coin_EOS.csv
# archive\coin_Ethereum.csv
# archive\coin_Iota.csv
# archive\coin_Litecoin.csv
# archive\coin_Monero.csv
# archive\coin_NEM.csv
# archive\coin_Polkadot.csv
# archive\coin_Solana.csv
# archive\coin_Stellar.csv
# archive\coin_Tether.csv
# archive\coin_Tron.csv
# archive\coin_Uniswap.csv
# archive\coin_USDCoin.csv
# archive\coin_WrappedBitcoin.csv
# archive\coin_XRP.csv

# %%
df = pd.read_csv('archive\coin_Bitcoin.csv')
df.head()
# Out:
#    SNo     Name Symbol                 Date        High         Low  \
# 0    1  Bitcoin    BTC  2013-04-29 23:59:59  147.488007  134.000000
# 1    2  Bitcoin    BTC  2013-04-30 23:59:59  146.929993  134.050003
# 2    3  Bitcoin    BTC  2013-05-01 23:59:59  139.889999  107.720001
# 3    4  Bitcoin    BTC  2013-05-02 23:59:59  125.599998   92.281898
# 4    5  Bitcoin    BTC  2013-05-03 23:59:59  108.127998   79.099998
#
#          Open       Close  Volume     Marketcap
# 0  134.444000  144.539993     0.0  1.603769e+09
# 1  144.000000  139.000000     0.0  1.542813e+09
# 2  139.000000  116.989998     0.0  1.298955e+09
# 3  116.379997  105.209999     0.0  1.168517e+09
# 4  106.250000   97.750000     0.0  1.085995e+09

# %%
df['Date'] = pd.to_datetime(df['Date']).dt.normalize()
df.head()
# Out:
#    SNo     Name Symbol       Date        High         Low        Open  \
# 0    1  Bitcoin    BTC 2013-04-29  147.488007  134.000000  134.444000
# 1    2  Bitcoin    BTC 2013-04-30  146.929993  134.050003  144.000000
# 2    3  Bitcoin    BTC 2013-05-01  139.889999  107.720001  139.000000
# 3    4  Bitcoin    BTC 2013-05-02  125.599998   92.281898  116.379997
# 4    5  Bitcoin    BTC 2013-05-03  108.127998   79.099998  106.250000
#
#         Close  Volume     Marketcap
# 0  144.539993     0.0  1.603769e+09
# 1  139.000000     0.0  1.542813e+09
# 2  116.989998     0.0  1.298955e+09
# 3  105.209999     0.0  1.168517e+09
# 4   97.750000     0.0  1.085995e+09

# %%
df['Date'] = pd.to_datetime(df['Date']).dt.normalize()
df['Year'] = pd.DatetimeIndex(df['Date']).year
Btc_2014 = df
# Out:
#    SNo     Name Symbol       Date        High         Low        Open  \
# 0    1  Bitcoin    BTC 2013-04-29  147.488007  134.000000  134.444000
# 1    2  Bitcoin    BTC 2013-04-30  146.929993  134.050003  144.000000
# 2    3  Bitcoin    BTC 2013-05-01  139.889999  107.720001  139.000000
# 3    4  Bitcoin    BTC 2013-05-02  125.599998   92.281898  116.379997
# 4    5  Bitcoin    BTC 2013-05-03  108.127998   79.099998  106.250000
#
#         Close  Volume     Marketcap  Year
# 0  144.539993     0.0  1.603769e+09  2013
# 1  139.000000     0.0  1.542813e+09  2013
# 2  116.989998     0.0  1.298955e+09  2013
# 3  105.209999     0.0  1.168517e+09  2013
# 4   97.750000     0.0  1.085995e+09  2013

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2991 entries, 0 to 2990
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   SNo        2991 non-null   int64
#  1   Name       2991 non-null   object
#  2   Symbol     2991 non-null   object
#  3   Date       2991 non-null   datetime64[ns]
#  4   High       2991 non-null   float64
#  5   Low        2991 non-null   float64
#  6   Open       2991 non-null   float64
#  7   Close      2991 non-null   float64
#  8   Volume     2991 non-null   float64
#  9   Marketcap  2991 non-null   float64
# dtypes: datetime64[ns](1), float64(6), int64(1), object(2)
# memory usage: 233.8+ KB

# %%
df.describe()
# Out:
#                SNo          High           Low          Open         Close  \
# count  2991.000000   2991.000000   2991.000000   2991.000000   2991.000000
# mean   1496.000000   6893.326038   6486.009539   6700.146240   6711.290443
# std     863.571653  11642.832456  10869.032130  11288.043736  11298.141921
# min       1.000000     74.561096     65.526001     68.504997     68.431000
# 25%     748.500000    436.179001    422.879486    430.445496    430.569489
# 50%    1496.000000   2387.610107   2178.500000   2269.889893   2286.409912
# 75%    2243.500000   8733.926948   8289.800459   8569.656494   8576.238715
# max    2991.000000  64863.098908  62208.964366  63523.754869  63503.457930
#
#              Volume     Marketcap
# count  2.991000e+03  2.991000e+03
# mean   1.090633e+10  1.208761e+11
# std    1.888895e+10  2.109438e+11
# min    0.000000e+00  7.784112e+08
# 25%    3.036725e+07  6.305579e+09
# 50%    9.460360e+08  3.741503e+10
# 75%    1.592015e+10  1.499957e+11
# ...

# %%
df.shape
# Out:
# (2991, 10)

# %%
plt.figure(figsize=(12,8))
plt.plot(df['Date'], df['Close'])
plt.show()

# %%
High_Value=df[df.High == df.High.max()]
High_Value
# Out:
#        SNo     Name Symbol       Date          High          Low  \
# 2907  2908  Bitcoin    BTC 2021-04-14  64863.098908  61554.79669
#
#               Open         Close        Volume     Marketcap  Year
# 2907  63523.754869  63109.695935  7.745178e+10  1.179061e+12  2021

# %%
active_days = 0
coin_number = 0
for coin in os.listdir('archive'):
    df = pd.read_csv("archive/"+coin)
    df['Date'] = pd.to_datetime(df['Date']).dt.normalize()
    coin_number += 1
    if active_days < df.shape[0]:
        active_days = df.shape[0]        
data = np.zeros((coin_number,active_days))
data[:] = np.nan

# %%
coin_id = 0
coin_name = ""
for coin in os.listdir('archive'):
    df = pd.read_csv("archive/"+coin)
    df['Date'] = pd.to_datetime(df['Date']).dt.normalize()
    coin_name = df['Name'][0]
    df.shape[0]
    data[coin_id,0:df.shape[0]] = df['Close'].values
    coin_id += 1
